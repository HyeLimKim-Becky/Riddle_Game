# %%
import sys
import random

def main(): 
    global Name 
    global Reason

    print(f"{'*'*50}")
    print("    Hello! welcome to \'Treasure of Egypt\' game!")
    input('<Press Enter to Continue>\n')  
    
    print("""
    You are a traveler looking for the most precious treasure of EGYPT. You have traveled for a long time and finally found out
    where the treasure was. But Sphinx was guarding the treasure and you must answer 3 questions to achieve the treasure.
    So traveler, what is your name?
    """)
    Name = input('Type your name : \n')

    print(f"""
    Hello {Name}, What do you want to do with the treasure?\n""")
    Reason = input('Type your reason : \n')

    print(f"""
    Perfect plan, {Name}! 
    So, Have you heard about Sphinx? 
    1. Yes
    2. No
    >>Press Enter
    """)
        
    isValidInput = False
    while isValidInput == False:
        Sp_answer = input(">")
        isValidInput = Start(Sp_answer)
    print(input(f"""    {Name}, Good Luck. Let's START!! *_*\n<Press Enter to Continue>"""))
   
    Question()

def Start(Sp_answer):      
    yes = "yes"
    y = "y"
    no = "no"
    n = "n"
    ans = Sp_answer.lower()
    if ans == yes or ans == y or ans == str(1):
        print("    Perfect. BE CAREFUL!!")
        return True
    elif ans == no or ans == n or ans == str(2):
        print("""
    Sphinx is a mythical creature with head of human and body of lion.
    If you can't solve the questions you will be killed and be eaten by Sphinx.
    BE CAREFUL!!
    """)
        return True
    else:
        print("    Invalid Answer. Try again.")
        return False

    print("<Press Enter to Continue>")   

def Question(): 
    print("    Now you have met Sphinx. Get ready to answer the question.")
    I = input("<Press Enter to Continue OR '8' to Exit>\n")
    
    if I == '8':
        Fail()
    else:
        print(f"""
    {Name} : I'm here to get the treasure. Give me 3 questions!              
    Sphinx : Ok, let's see if you are qualified to take the treasure or not. 

            For the 3 main questions, you will get 2 chances each to get the correct answer or else you will die.
            There are 5 choices for each one. 
            
            Bue before you get to the question, you will play a \'Rock, scissors, paper game\'.
            If you win me at least 3 times there out of 5 times, I will reduce one of your choices for the main questions.

            Ready for \'Rock, scissors, paper game\' ??
            """)
    I = input("<Press Enter to Continue OR '8' to Exit>\n")

    if I == '8':
        Fail()
    else:
        RPS()
    
def RPS():
    print("~"*15,"\'Rock, Scissors, Paper Game\'","~"*15)
    round = 1

    T_win = 0
    S_win = 0
    
    # Traveler's RPS
    while round <= 5:
        
        print(f"\n- ROUND {round}- \n")

        T_RPS = input(f"{Name} = Type [R for Rock/S for Scissors/P for Paper] \n>> ")

        rock = 'rock'
        scissors = 'scissors'
        paper = 'paper'
        r = 'r'
        s = 's'
        p = 'p'
        T = T_RPS.lower()

        #Sphinx's RPS    
        S_RPS = random.choice("rsp")

        if S_RPS == "r":
            print("Sphinx = Rock\n")
        elif S_RPS == "s":
            print("Sphinx = Scissors\n")
        elif S_RPS == "p":
            print("Sphinx = Paper\n")
        else:
            print("Something is wrong.\n")

        while T == rock or T == r:
            if S_RPS == "s":
                T_win += 1
                print(f"{Name} win")
            else:
                S_win += 1
                print("Sphinx win")
            round += 1
            break

        while T == scissors or T == s:
            if S_RPS == "p":
                T_win += 1
                print(f"{Name} win")
            else:
                S_win += 1
                print("Sphinx win")
            round += 1
            break

        while T == paper or T == p:
            if S_RPS == "r":
                T_win += 1
                print(f"{Name} win")
            else:
                S_win += 1
                print("Sphinx win")
            round += 1
            break 
                          
    print(f"\n    {Name} : {T_win} wins vs Sphinx : {S_win} wins")
        
    if T_win > S_win:
        print(f"    OK, {Name}. Since you win I will reduce one of the choices as I promised.")
        I = input("<Press Enter to Continue OR '8' to Exit>\n")

        if I == '8':
            Fail()
        else:
            QuestionH1()

    elif T_win < S_win:
        print(f"    Since you lose, you will have 5 choices. Good luck, {Name}.")
        I = input("<Press Enter to Continue OR '8' to Exit>\n")

        if I == '8':
            Fail()
        else:
            Question1()
        
def Question1():
    print(f"{'_'*70}")
   
    print(f"- QUESTION 1 -")
    chances = 2
          
    while chances > 0:      
        Q1 = input(f"""
    Sphinx : Here is your first question.
             Some try to hide, some try to cheat; but time will show, we will always meet.
             What is this?
             1. Death
             2. Tree
             3. Star
             4. Moon
             5. Fish
                
             Ans : """)

        death = "death"
        tree = "tree"
        star = "star"
        moon = "moon"
        fish = "fish"
        ans_1 = Q1.lower()

        if ans_1 == death or ans_1 == str(1):
            print("    YOU ARE CORRECT")
            input('<Press Enter to Continue>\n')
            Question2()
        
        elif ans_1 == tree or ans_1 == star or ans_1 == moon or ans_1 == fish:
            print("    WRONG ANSWER!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        elif ans_1 == str(2) or ans_1 == str(3) or ans_1 == str(4) or ans_1 == str(5):
            print("    WRONG CHOICE!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        else:
            print("    Invalid")
            if chances == 2:
                print(f"""    You still have {chances} more chance left. 
    But it will be counted down next time. STOP PLAYING and Choose from given choices!""")  
            else:
                chances -= 1
                print(f"AGAIN???? Now you have {chances} left. Choose from given choices!")

    print(f"{'_'*70}")
    print(f"{'_'*70}")

    Fail()   

def QuestionH1():
    print(f"{'_'*70}")
    
    print(f"- QUESTION 1 -")
    
    chances = 2
          
    while chances > 0:      
        Q1 = input(f"""
    Sphinx : Here is your first question.
             Some try to hide, some try to cheat; but time will show, we will always meet.
             What is this?
             1. Death
             2. Tree
             3. Star
             4. Moon
                                 
             Ans : """)

        death = "death"
        tree = "tree"
        star = "star"
        moon = "moon"
    
        ans_1 = Q1.lower()

        if ans_1 == death or ans_1 == str(1):
            print("    YOU ARE CORRECT")
            input('<Press Enter to Continue>\n')
            QuestionH2()
        elif ans_1 == tree or ans_1 == star or ans_1 == moon:
            print("    WRONG ANSWER!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        elif ans_1 == str(2) or ans_1 == str(3) or ans_1 == str(4):
            print("    WRONG CHOICE!") 
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        else:
            print("    Invalid")
            if chances == 2:
                print(f"""    You still have {chances} more chance left. 
    But it will be counted down next time. STOP PLAYING and Choose from given choices!""")  
            else:
                chances -= 1
                print(f"AGAIN???? Now you have {chances} left. Choose from given choices!")          
   
    print(f"{'_'*70}")
    print(f"{'_'*70}")
    Fail()


def Question2():
    print(f"{'_'*70}")

    print(f"- QUESTION 2 -")
    chances = 2
            
    while chances > 0:      
        Q2 = input(f"""
    Sphinx : Here is your second question. What is always old and sometimes new; never sad, sometimes blue; 
             never empty, but sometimes full; never pushes, always pulls?
             1. Sun
             2. Love
             3. Moon
             4. Fish
             5. Tree
              
             Ans : """)
       
        sun = "sun"
        love = "love"
        moon = "moon"
        fish = "fish"
        tree = "tree"
              
        ans_2 = Q2.lower()
    
        if ans_2 == moon or ans_2 == str(3):
            print("    YOU ARE CORRECT")
            input('<Press Enter to Continue>\n')
            Question3()
        elif ans_2== sun or ans_2 == love or ans_2 == fish or ans_2 == tree:
            print("    WRONG ANSWER!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        elif ans_2 == str(1) or ans_2 == str(2) or ans_2 == str(4) or ans_2 == str(5):
            print("    WRONG CHOICE!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
        else:
            print("    Invalid")
            if chances == 2:
                print(f"""    You still have {chances} more chance left. 
    But it will be counted down next time. STOP PLAYING and Choose from given choices!""")  
            else:
                chances -= 1
                print(f"AGAIN???? Now you have {chances} left. Choose from given choices!") 
            
    print(f"{'_'*70}")
    print(f"{'_'*70}")  
    Fail()

def QuestionH2():
    print(f"{'_'*70}")

    print(f"- QUESTION 2 -")
    chances = 2
            
    while chances > 0:      
        Q2 = input(f"""
    Sphinx : Here is your second question. 
             What is always old and sometimes new; never sad, sometimes blue; 
             never empty, but sometimes full; never pushes, always pulls?
             1. Sun
             2. Love
             3. Moon
             4. Fish
                
             Ans : """)
        
        sun = "sun"
        love = "love"
        moon = "moon"
        fish = "fish"
        ans_2 = Q2.lower()
    
        if ans_2 == moon or ans_2 == str(3):
            print("    YOU ARE CORRECT")
            input('<Press Enter to Continue>\n')
            QuestionH3()
            
        elif ans_2== sun or ans_2 == love or ans_2 == fish: 
            print("    WRONG ANSWER!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        elif ans_2 == str(1) or ans_2 == str(2) or ans_2 == str(4):
            print("    WRONG CHOICE!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        else:
            print("    Invalid")
            if chances == 2:
                print(f"""    You still have {chances} more chance left. 
    But it will be counted down next time. STOP PLAYING and Choose from given choices!""")  
            else:
                chances -= 1
                print(f"AGAIN???? Now you have {chances} left. Choose from given choices!")

    print(f"{'_'*70}")
    print(f"{'_'*70}") 
    Fail()
          
def Question3():
    print(f"{'_'*70}")

    print(f"- QUESTION 3 -")
    chances = 2
            
    while chances > 0:      
        Q3 = input(f"""
    Sphinx : You made it to last question. You are very smart.
             Here is your last question.
             What can run, but never walks; has a mouth, but never talks; has a head,
             but never weeps; has a bed, but never sleeps?
             1. Fish
             2. Sun
             3. Spider
             4. Candy
             5. River
                
             Ans : """)
        
        fish = "fish"
        sun = "sun"
        spider = "spider"
        candy = "candy"
        river = "river"
        ans_3 = Q3.lower()
        if ans_3 == river or ans_3 == str(5):
            print("    YOU ARE CORRECT")
            input('<Press Enter to Continue>\n')
            win()
           
        elif ans_3== fish or ans_3 == sun or ans_3 == spider or ans_3 == candy: 
            print("    WRONG ANSWER!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        elif ans_3 == str(1) or ans_3 == str(2) or ans_3 == str(3) or ans_3 == str(4):
            print("    WRONG CHOICE!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        else:
            print("    Invalid")
            if chances == 2:
                print(f"""    You still have {chances} more chance left. 
    But it will be counted down next time. STOP PLAYING and Choose from given choices!""")  
            else:
                chances -= 1
                print(f"AGAIN???? Now you have {chances} left. Choose from given choices!")

    print(f"{'_'*70}")
    print(f"{'_'*70}")    
    Fail()
      
def QuestionH3():
    print(f"{'_'*70}")

    print(f"- QUESTION 3 -")
    chances = 2
            
    while chances > 0:      
        Q3 = input(f"""
    Sphinx : You made it to last question. You are very smart.
             Here is your last question.
             What can run, but never walks; has a mouth, but never talks; has a head,
             but never weeps; has a bed, but never sleeps?
             1. Fish
             2. River
             3. Spider
             4. Candy
                            
             Ans : """)
        fish = "fish"
        spider = "spider"
        candy = "candy"
        river = "river"
        ans_3 = Q3.lower()
        if ans_3 == river or ans_3 == str(2):
            print("    YOU ARE CORRECT")
            input('<Press Enter to Continue>\n')
            win()
        elif ans_3== fish or ans_3 == spider or ans_3 == candy:
            print("    WRONG ANSWER!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        elif ans_3 == str(1) or ans_3 == str(3) or ans_3 == str(4):
            print("    WRONG CHOICE!")
            chances -= 1
            print(f"""    You have {chances} more chance left""")
      
        else:
            print("    Invalid")
            if chances == 2:
                print(f"""    You still have {chances} more chance left. 
    But it will be counted down next time. STOP PLAYING and Choose from given choices!""")  
            else:
                chances -= 1
                print(f"AGAIN???? Now you have {chances} left. Choose from given choices!")

       
    Fail()
          
def Fail():
    print("   You Are Dead :( ")
    
    play_again = input("   Would you like to play again? Y/N \n")
    y = 'y'
    yes = 'yes'
    n = 'n'
    no = 'no'
    p = play_again.lower()
    if "y" in p or "yes" in p:
        print(f"   I hope you win this time for {Reason}!!")
        input("<Press Enter to restart>\n")
        Question()
    elif 'n' in p or "no" in p: 
        print(f"   I feel so sad. But promise me that you will come back, {Name}!!")
        input("<Press any key to exit>\n")
        print(f"\n\n{'*'*50}")
        sys.exit(0)
    else:
        print("   Invalid Answer.")


    sys.exit(0)

def win():
    print(f"   CONGRATULATION! YOU ACHIEVED THE TREASURE :) I hope you have enough for {Reason}, {Name}")
    print(f"\n\n{'*'*50}")
          
          
          g
    sys.exit(0)

main()
